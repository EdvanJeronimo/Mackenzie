# %% [markdown]
# <a href="https://colab.research.google.com/github/EdvanJeronimo/Mackenzie/blob/main/Trilha1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request  

texto = []

for line in urllib.request.urlopen('https://www.gutenberg.org/cache/epub/25313/pg25313.txt'): 
    texto.append(line.decode('utf-8'))

for i in range(len(texto)):
    texto[i] = texto[i].lower()
    texto[i] = texto[i].replace('\n','')
    texto[i] = texto[i].replace('.','')
    texto[i] = texto[i].replace(',','')
    texto[i] = texto[i].replace('(','')
    texto[i] = texto[i].replace(')','')
    texto[i] = texto[i].replace('?','')
    texto[i] = texto[i].replace('\'','')

# %%
dicionario = {}                             

for linha in texto:

  linha = linha.lower()                   
  palavras = linha.split()                


  for palavra in palavras:                    
    if palavra not in dicionario.keys():    
      dicionario[palavra] = 1               
    else:                                 
      dicionario[palavra] =  dicionario[palavra] + 1  

print(dicionario)
# Out:
# {'\ufeffthe': 1, 'project': 82, 'gutenberg': 24, 'ebook': 10, 'of': 121, 'um': 476, 'conto': 14, 'portuguez:': 3, 'episodio': 4, 'da': 1062, 'guerra': 32, 'civil:': 3, 'a': 2145, 'maria': 178, 'fonte': 5, 'by': 22, 'miguel': 10, 'j': 7, 't': 8, 'mascarenhas': 7, 'this': 47, 'is': 25, 'for': 26, 'the': 173, 'use': 11, 'anyone': 5, 'anywhere': 2, 'at': 15, 'no': 311, 'cost': 3, 'and': 68, 'with': 47, 'almost': 2, 'restrictions': 2, 'whatsoever': 2, 'you': 68, 'may': 16, 'copy': 12, 'it': 15, 'give': 4, 'away': 2, 'or': 78, 're-use': 2, 'under': 6, 'terms': 21, 'license': 15, 'included': 3, 'online': 4, 'wwwgutenbergorg': 3, 'title:': 1, 'author:': 1, 'release': 1, 'date:': 1, '3': 4, '2008': 1, '[ebook': 1, '#25313]': 1, 'language:': 1, 'portuguese': 1, '***': 7, 'start': 2, 'portuguez': 30, 'produced': 5, 'manuela': 2, 'alves': 3, 'e': 1862, 'pedro': 14, 'saborano': 2, 'from': 19, 'scanned': 2, 'images': 2, 'public': 11, 'domain': 10, 'material': 8, 'google': 2, 'book': 2, 'search': 3
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.DataFrame(mydict.items(),  columns=['Palavras', 'Quantidade']).sort_values('Quantidade', ascending=False)
df = df[df['Quantidade'] > 100] # somente palavras que se repetiram mais de 100 vezes

# Visualizando em gráfico de barras
plt.figure(figsize=(24,10))
mpl.style.use(['seaborn'])

sns.barplot(x=df.Palavras,y=df['Quantidade'])
plt.xticks(rotation=90) 
plt.show()

# Visualizando em gráfico de linha
plt.figure(figsize=(15,12))
sns.set_theme(style="whitegrid")
sns.lineplot(x=df['Quantidade'],y=df.Palavras, palette="tab10", size_norm=100, linewidth=2)
